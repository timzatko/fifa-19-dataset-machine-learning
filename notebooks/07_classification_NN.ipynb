# %% [markdown]
# # Classification Neural Network

# %%
# %load_ext autoreload
# %autoreload 2

# !python --version
# Out:
# Python 3.7.6

# %%
import sys
sys.path.append('..')

# %%
from src.dataset import DatasetForClassification

# %%
from src.evaluation import custom_classification_report_nn

# %% [markdown]
# ## Load the dataset

# %%
dataset = DatasetForClassification('../data/fifa_processed_for_cls.csv', ['Position (4)', 'Position (13)'])

# %% [markdown]
# ## Model

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.utils import to_categorical


def baseline_model(input_dim, output_dim):
    model = Sequential()
    
    model.add(Dense(64, activation='relu', input_dim=input_dim))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(output_dim, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %% [markdown]
# ## Classification of "Position (4)"

# %%
X_train, X_test, y_train, y_test = dataset.get_data('Position (4)')

labels = dataset.get_labels('Position (4)')
features = len(X_train.columns)
classes = 4

# %%
model = baseline_model(features, classes)

model.fit(X_train,
          to_categorical(y_train, classes),
          epochs=100,
          batch_size=128,
          validation_split=0.1)

custom_classification_report_nn(model, labels, X_test, y_test)
# Out:
# Train on 13065 samples, validate on 1452 samples
# Epoch 1/100
# 13065/13065 [==============================] - 1s 73us/sample - loss: 13.7537 - accuracy: 0.4008 - val_loss: 0.7177 - val_accuracy: 0.7121
# Epoch 2/100
# 13065/13065 [==============================] - 0s 29us/sample - loss: 1.2794 - accuracy: 0.5482 - val_loss: 0.6146 - val_accuracy: 0.7679
# Epoch 3/100
# 13065/13065 [==============================] - 0s 32us/sample - loss: 0.9131 - accuracy: 0.6220 - val_loss: 0.5623 - val_accuracy: 0.7893
# Epoch 4/100
# 13065/13065 [==============================] - 0s 28us/sample - loss: 0.7906 - accuracy: 0.6706 - val_loss: 0.5239 - val_accuracy: 0.8030
# Epoch 5/100
# 13065/13065 [==============================] - 0s 26us/sample - loss: 0.7171 - accuracy: 0.6965 - val_loss: 0.5018 - val_accuracy: 0.8079
# Epoch 6/100
# 13065/13065 [==============================] - 0s 28us/sample - loss: 0.6719 - accuracy: 0.7147 - val_loss: 0.4708 - val_accuracy: 0.8154
# Epoch 7/100
# ...

# %% [markdown]
# ## Classification of "Position (13)"

# %%
X_train, X_test, y_train, y_test = dataset.get_data('Position (13)')

labels = dataset.get_labels('Position (13)')
features = len(X_train.columns)
classes = 13

# %%
model = baseline_model(features, classes)

model.fit(X_train,
          to_categorical(y_train, classes),
          epochs=100,
          batch_size=128,
          validation_split=0.1)

custom_classification_report_nn(model, labels, X_test, y_test)
# Out:
# Train on 13065 samples, validate on 1452 samples
# Epoch 1/100
# 13065/13065 [==============================] - 1s 70us/sample - loss: 20.9350 - accuracy: 0.1733 - val_loss: 2.0480 - val_accuracy: 0.3168
# Epoch 2/100
# 13065/13065 [==============================] - 1s 50us/sample - loss: 2.2256 - accuracy: 0.2436 - val_loss: 1.9342 - val_accuracy: 0.3085
# Epoch 3/100
# 13065/13065 [==============================] - 1s 51us/sample - loss: 2.0937 - accuracy: 0.2888 - val_loss: 1.8757 - val_accuracy: 0.3822
# Epoch 4/100
# 13065/13065 [==============================] - 0s 38us/sample - loss: 2.0293 - accuracy: 0.3139 - val_loss: 1.8782 - val_accuracy: 0.3891
# Epoch 5/100
# 13065/13065 [==============================] - 0s 38us/sample - loss: 1.9985 - accuracy: 0.3330 - val_loss: 1.8160 - val_accuracy: 0.3981
# Epoch 6/100
# 13065/13065 [==============================] - 1s 39us/sample - loss: 1.9510 - accuracy: 0.3437 - val_loss: 1.7883 - val_accuracy: 0.3967
# Epoch 7/100
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The neural network model is similiar to other models in its performance (logistic regression/random forest).
