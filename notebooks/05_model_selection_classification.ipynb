# %% [markdown]
# # Model selection (classification)

# %%
# %load_ext autoreload
# %autoreload 2

# !python --version
# Out:
# Python 3.7.6

# %%
import sys
sys.path.append('..')

# %%
from src.dataset import DatasetForClassification

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import LinearSVC

# %%
from src.evaluation import custom_classification_report

# %% [markdown]
# ## Load the dataset

# %%
dataset = DatasetForClassification('../data/fifa_processed_for_cls.csv', ['Position (4)', 'Position (13)'])

# %% [markdown]
# ## Classification of "Position (4)"

# %%
X_train, X_test, y_train, y_test = dataset.get_data('Position (4)')

labels = dataset.get_labels('Position (4)')

# %% [markdown]
# ### DecisionTreeClassifier

# %%
# %%time

clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attack
# precision: 0.7676470588235295
# recall: 0.7131147540983607
# f1-score: 0.7393767705382438
# support: 732
#
#
# defense
# precision: 0.8729472774416595
# recall: 0.8790252393385553
# f1-score: 0.8759757155247181
# support: 1149
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# middle
# precision: 0.7510822510822511
# recall: 0.7757078986587184
# f1-score: 0.7631964809384165
# support: 1342
#
#
# accuracy: 0.8209366391184573
#
#
# macro avg
# precision: 0.8479191468368601
# recall: 0.8419619730239085
# f1-score: 0.8446372417503446
# support: 3630
#
#
# weighted avg
# precision: 0.8209053580693308
# recall: 0.8209366391184573
# f1-score: 0.8206417549838155
# support: 3630
#
#
# CPU times: user 415 ms, sys: 0 ns, total: 415 ms
# Wall time: 416 ms

# %% [markdown]
# ### LogisticRegressionCV

# %%
# %%time

clf = LogisticRegressionCV(max_iter=10000)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attack
# precision: 0.8191176470588235
# recall: 0.8288690476190477
# f1-score: 0.8239644970414202
# support: 672
#
#
# defense
# precision: 0.9343128781331028
# recall: 0.9416376306620209
# f1-score: 0.9379609544468546
# support: 1148
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# middle
# precision: 0.8715728715728716
# recall: 0.8610121168923734
# f1-score: 0.8662603083542488
# support: 1403
#
#
# accuracy: 0.8961432506887053
#
#
# macro avg
# precision: 0.9062508491911995
# recall: 0.9078796987933606
# f1-score: 0.907046439960631
# support: 3630
#
#
# weighted avg
# precision: 0.8961033007540139
# recall: 0.8961432506887053
# f1-score: 0.896100972544858
# support: 3630
#
#
# CPU times: user 7min 1s, sys: 5min 39s, total: 12min 40s
# Wall time: 3min 11s

# %% [markdown]
# ### LinearSVC

# %%
# %%time

clf = LinearSVC(max_iter=10000)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# attack
# precision: 0.9838235294117647
# recall: 0.43413367942894227
# f1-score: 0.6024313372354796
# support: 1541
#
#
# defense
# precision: 0.9922212618841832
# recall: 0.6966019417475728
# f1-score: 0.8185383244206774
# support: 1648
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# middle
# precision: 0.023088023088023088
# recall: 0.9411764705882353
# f1-score: 0.04507042253521127
# support: 34
#
#
# accuracy: 0.6214876033057851
#
#
# macro avg
# precision: 0.7497832035959927
# recall: 0.7679780229411877
# f1-score: 0.616510021047842
# support: 3630
#
#
# weighted avg
# precision: 0.9804511545988034
# recall: 0.6214876033057851
# f1-score: 0.7398981387579469
# support: 3630
#
#
# CPU times: user 48.1 s, sys: 0 ns, total: 48.1 s
# Wall time: 47.8 s

# %% [markdown]
# ## Classification of "Position (13)"

# %%
X_train, X_test, y_train, y_test = dataset.get_data('Position (13)')

labels = dataset.get_labels('Position (13)')

# %% [markdown]
# ### DecisionTreeClassifier

# %%
# %%time

clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attacking midfielder
# precision: 0.2611111111111111
# recall: 0.235
# f1-score: 0.24736842105263157
# support: 200
#
#
# central attack
# precision: 0.6757369614512472
# recall: 0.6772727272727272
# f1-score: 0.6765039727582293
# support: 440
#
#
# central defense
# precision: 0.5648854961832062
# recall: 0.5481481481481482
# f1-score: 0.5563909774436091
# support: 270
#
#
# deffensive midfielder
# precision: 0.34545454545454546
# recall: 0.34296028880866425
# f1-score: 0.34420289855072467
# support: 277
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# left attack
# precision: 0.1111111111111111
# recall: 0.09923664122137404
# f1-score: 0.10483870967741936
# support: 131
#
#
# left defense
# precision: 0.6433823529411765
# recall: 0.6227758007117438
# f1-score: 0.6329113924050632
# support: 281
#
#
# left midfielder
# precision: 0.22943722943722944
# recall: 0.22844827586206898
# f1-score: 0.2289416846652268
# support: 232
#
#
# middle
# precision: 0.06896551724137931
# recall: 0.05405405405405406
# f1-score: 0.06060606060606061
# support: 37
#
#
# midfielder
# precision: 0.44251626898047725
# recall: 0.48
# f1-score: 0.4604966139954853
# support: 425
#
#
# right attack
# precision: 0.10655737704918032
# recall: 0.104
# f1-score: 0.10526315789473684
# support: 125
#
#
# right defense
# precision: 0.8164983164983165
# recall: 0.8016528925619835
# f1-score: 0.8090075062552127
# support: 605
#
#
# right midfielder
# precision: 0.19665271966527198
# recall: 0.235
# f1-score: 0.214123006833713
# support: 200
#
#
# accuracy: 0.5473829201101928
#
#
# macro avg
# precision: 0.42017761593263475
# recall: 0.4175806791262126
# f1-score: 0.41851187708754717
# support: 3630
#
#
# weighted avg
# precision: 0.5483704540724315
# recall: 0.5473829201101928
# f1-score: 0.5475997698861883
# support: 3630
#
#
# CPU times: user 487 ms, sys: 0 ns, total: 487 ms
# Wall time: 486 ms

# %% [markdown]
# ### LogisticRegressionCV

# %%
# %%time

clf = LogisticRegressionCV(max_iter=100)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# attacking midfielder
# precision: 0.5166666666666667
# recall: 0.4946808510638298
# f1-score: 0.5054347826086957
# support: 188
#
#
# central attack
# precision: 0.9410430839002267
# recall: 0.7021996615905245
# f1-score: 0.8042635658914729
# support: 591
#
#
# central defense
# precision: 0.8740458015267175
# recall: 0.7089783281733746
# f1-score: 0.7829059829059829
# support: 323
#
#
# deffensive midfielder
# precision: 0.5527272727272727
# recall: 0.6229508196721312
# f1-score: 0.5857418111753372
# support: 244
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# left attack
# precision: 0.05128205128205128
# recall: 0.2222222222222222
# f1-score: 0.08333333333333333
# support: 27
#
#
# left defense
# precision: 0.8051470588235294
# recall: 0.8264150943396227
# f1-score: 0.8156424581005587
# support: 265
#
#
# left midfielder
# precision: 0.24675324675324675
# recall: 0.34545454545454546
# f1-score: 0.2878787878787879
# support: 165
#
#
# middle
# precision: 0.0
# recall: 0.0
# f1-score: 0.0
# support: 0
#
#
# midfielder
# precision: 0.806941431670282
# recall: 0.6514886164623468
# f1-score: 0.7209302325581396
# support: 571
#
#
# right attack
# precision: 0.040983606557377046
# recall: 0.23809523809523808
# f1-score: 0.06993006993006992
# support: 21
#
#
# right defense
# precision: 0.9276094276094277
# recall: 0.9198664440734557
# f1-score: 0.9237217099748534
# support: 599
#
#
# right midfielder
# precision: 0.35564853556485354
# recall: 0.37117903930131
# f1-score: 0.36324786324786323
# support: 229
#
#
# accuracy: 0.7137741046831956
#
#
# macro avg
# precision: 0.5476037063908963
# recall: 0.5464254508037386
# f1-score: 0.5340792767388535
# support: 3630
#
#
# weighted avg
# precision: 0.7800663060738079
# recall: 0.7137741046831956
# f1-score: 0.740674697408343
# support: 3630
#
#
# CPU times: user 4min 51s, sys: 4min 19s, total: 9min 10s
# Wall time: 2min 19s

# %% [markdown]
# ### LinearSVC

# %%
# %%time

clf = LinearSVC(max_iter=100)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# attacking midfielder
# precision: 0.22777777777777777
# recall: 0.5540540540540541
# f1-score: 0.3228346456692914
# support: 74
#
#
# central attack
# precision: 0.8934240362811792
# recall: 0.7476280834914611
# f1-score: 0.8140495867768595
# support: 527
#
#
# central defense
# precision: 0.7480916030534351
# recall: 0.717948717948718
# f1-score: 0.7327102803738318
# support: 273
#
#
# deffensive midfielder
# precision: 0.8036363636363636
# recall: 0.33586626139817627
# f1-score: 0.47374062165058944
# support: 658
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# left attack
# precision: 0.017094017094017096
# recall: 0.05405405405405406
# f1-score: 0.02597402597402598
# support: 37
#
#
# left defense
# precision: 0.7941176470588235
# recall: 0.8181818181818182
# f1-score: 0.8059701492537314
# support: 264
#
#
# left midfielder
# precision: 0.017316017316017316
# recall: 0.4
# f1-score: 0.03319502074688796
# support: 10
#
#
# middle
# precision: 0.0
# recall: 0.0
# f1-score: 0.0
# support: 1
#
#
# midfielder
# precision: 0.0
# recall: 0.0
# f1-score: 0.0
# support: 0
#
#
# right attack
# precision: 0.00819672131147541
# recall: 0.16666666666666666
# f1-score: 0.015625
# support: 6
#
#
# right defense
# precision: 0.9461279461279462
# recall: 0.8541033434650456
# f1-score: 0.8977635782747604
# support: 658
#
#
# right midfielder
# precision: 0.7322175732217573
# recall: 0.24475524475524477
# f1-score: 0.36687631027253664
# support: 715
#
#
# accuracy: 0.6112947658402204
#
#
# macro avg
# precision: 0.4759999771445225
# recall: 0.4533275572319415
# f1-score: 0.42221070915327036
# support: 3630
#
#
# weighted avg
# precision: 0.8221215947506431
# recall: 0.6112947658402204
# f1-score: 0.6718603268650759
# support: 3630
#
#
# CPU times: user 6.97 s, sys: 1.02 s, total: 7.99 s
# Wall time: 7.64 s
