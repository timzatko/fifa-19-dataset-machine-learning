# %% [markdown]
# # Model selection (classification)

# %%
# %load_ext autoreload
# %autoreload 2

# !python --version
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Python 3.7.6

# %%
import sys
sys.path.append('..')

# %%
from src.dataset import DatasetForClassification

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import LinearSVC

# %%
from src.evaluation import custom_classification_report

# %% [markdown]
# ## Load the dataset

# %%
dataset = DatasetForClassification('../data/fifa_processed_for_cls.csv', ['Position (4)', 'Position (13)'])

# %% [markdown]
# ## Classification of "Position (4)"

# %%
X_train, X_test, y_train, y_test = dataset.get_data('Position (4)')

labels = dataset.get_labels('Position (4)')

# %% [markdown]
# ### DecisionTreeClassifier

# %%
# %%time

clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attack
# precision: 0.7676470588235295
# recall: 0.7160493827160493
# f1-score: 0.7409510290986516
# support: 729
#
#
# defense
# precision: 0.8703543647363872
# recall: 0.8673557278208441
# f1-score: 0.8688524590163934
# support: 1161
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# middle
# precision: 0.7474747474747475
# recall: 0.7771942985746436
# f1-score: 0.7620448694372931
# support: 1333
#
#
# accuracy: 0.818732782369146
#
#
# macro avg
# precision: 0.846369042758666
# recall: 0.8401498522778843
# f1-score: 0.8429620893880846
# support: 3630
#
#
# weighted avg
# precision: 0.8191404853237292
# recall: 0.818732782369146
# f1-score: 0.8186492606310914
# support: 3630
#
#
# CPU times: user 230 ms, sys: 30 ms, total: 260 ms
# Wall time: 259 ms

# %% [markdown]
# ### LogisticRegressionCV

# %%
# %%time

clf = LogisticRegressionCV(max_iter=10000)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attack
# precision: 0.8176470588235294
# recall: 0.8310911808669657
# f1-score: 0.8243143068939955
# support: 669
#
#
# defense
# precision: 0.9334485738980121
# recall: 0.941586748038361
# f1-score: 0.9374999999999999
# support: 1147
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# middle
# precision: 0.873015873015873
# recall: 0.8599857853589197
# f1-score: 0.8664518438954529
# support: 1407
#
#
# accuracy: 0.8961432506887053
#
#
# macro avg
# precision: 0.9060278764343536
# recall: 0.9081659285660616
# f1-score: 0.9070665376973621
# support: 3630
#
#
# weighted avg
# precision: 0.8961445537044889
# recall: 0.8961432506887053
# f1-score: 0.8961092329677645
# support: 3630
#
#
# CPU times: user 8min 57s, sys: 12min 5s, total: 21min 2s
# Wall time: 1min 19s

# %% [markdown]
# ### LinearSVC

# %%
# %%time

clf = LinearSVC(max_iter=10000)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attack
# precision: 0.7794117647058824
# recall: 0.8320251177394035
# f1-score: 0.8048595292331056
# support: 637
#
#
# defense
# precision: 0.9248055315471045
# recall: 0.9361329833770778
# f1-score: 0.9304347826086956
# support: 1143
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# middle
# precision: 0.8737373737373737
# recall: 0.8392238392238393
# f1-score: 0.8561329091551785
# support: 1443
#
#
# accuracy: 0.8865013774104683
#
#
# macro avg
# precision: 0.8944886674975902
# recall: 0.9018454850850801
# f1-score: 0.8978568052492448
# support: 3630
#
#
# weighted avg
# precision: 0.8874217760272777
# recall: 0.8865013774104683
# f1-score: 0.8866617808689118
# support: 3630
#
#
# CPU times: user 2.2 s, sys: 910 ms, total: 3.11 s
# Wall time: 1.79 s

# %% [markdown]
# ## Classification of "Position (13)"

# %%
X_train, X_test, y_train, y_test = dataset.get_data('Position (13)')

labels = dataset.get_labels('Position (13)')

# %% [markdown]
# ### DecisionTreeClassifier

# %%
# %%time

clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attacking midfielder
# precision: 0.3055555555555556
# recall: 0.2669902912621359
# f1-score: 0.28497409326424866
# support: 206
#
#
# central attack
# precision: 0.6870748299319728
# recall: 0.679372197309417
# f1-score: 0.6832018038331454
# support: 446
#
#
# central defense
# precision: 0.5725190839694656
# recall: 0.5454545454545454
# f1-score: 0.5586592178770949
# support: 275
#
#
# deffensive midfielder
# precision: 0.38181818181818183
# recall: 0.38181818181818183
# f1-score: 0.38181818181818183
# support: 275
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# left attack
# precision: 0.07692307692307693
# recall: 0.07692307692307693
# f1-score: 0.07692307692307693
# support: 117
#
#
# left defense
# precision: 0.625
# recall: 0.6439393939393939
# f1-score: 0.6343283582089552
# support: 264
#
#
# left midfielder
# precision: 0.24242424242424243
# recall: 0.23829787234042554
# f1-score: 0.24034334763948498
# support: 235
#
#
# middle
# precision: 0.0
# recall: 0.0
# f1-score: 0.0
# support: 39
#
#
# midfielder
# precision: 0.4750542299349241
# recall: 0.49547511312217196
# f1-score: 0.4850498338870432
# support: 442
#
#
# right attack
# precision: 0.14754098360655737
# recall: 0.14516129032258066
# f1-score: 0.14634146341463414
# support: 124
#
#
# right defense
# precision: 0.8249158249158249
# recall: 0.8153078202995009
# f1-score: 0.8200836820083681
# support: 601
#
#
# right midfielder
# precision: 0.21338912133891214
# recall: 0.2562814070351759
# f1-score: 0.2328767123287671
# support: 199
#
#
# accuracy: 0.5600550964187327
#
#
# macro avg
# precision: 0.42709347157067035
# recall: 0.42654009152512357
# f1-score: 0.42650767470792317
# support: 3630
#
#
# weighted avg
# precision: 0.5609642317285698
# recall: 0.5600550964187327
# f1-score: 0.5602585268822601
# support: 3630
#
#
# CPU times: user 460 ms, sys: 10 ms, total: 470 ms
# Wall time: 464 ms

# %% [markdown]
# ### LogisticRegressionCV

# %%
# %%time

clf = LogisticRegressionCV(max_iter=100)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# ### LinearSVC

# %%
# %%time

clf = LinearSVC(max_iter=100)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
