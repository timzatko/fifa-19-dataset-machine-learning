# %% [markdown]
# # Model selection (classification)

# %%
# %load_ext autoreload
# %autoreload 2

# !python --version
# Out:
# Python 3.7.6

# %%
import sys
sys.path.append('..')

# %%
from src.dataset import DatasetForClassification

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import LinearSVC

# %%
from src.evaluation import custom_classification_report

# %% [markdown]
# ## Load the dataset

# %%
dataset = DatasetForClassification('../data/fifa_processed_for_cls.csv', ['Position (4)', 'Position (13)'])

# %% [markdown]
# ## Classification of "Position (4)"

# %%
X_train, X_test, y_train, y_test = dataset.get_data('Position (4)')

labels = dataset.get_labels('Position (4)')

# %% [markdown]
# ### DecisionTreeClassifier

# %%
# %%time

clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attack
# precision: 0.7544117647058823
# recall: 0.7184873949579832
# f1-score: 0.7360114777618364
# support: 714
#
#
# defense
# precision: 0.8712186689714779
# recall: 0.8742411101474414
# f1-score: 0.8727272727272726
# support: 1153
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# middle
# precision: 0.7582972582972582
# recall: 0.7750737463126843
# f1-score: 0.7665937272064186
# support: 1356
#
#
# accuracy: 0.8206611570247934
#
#
# macro avg
# precision: 0.8459819229936547
# recall: 0.8419505628545273
# f1-score: 0.8438331194238818
# support: 3630
#
#
# weighted avg
# precision: 0.8205003326653433
# recall: 0.8206611570247934
# f1-score: 0.8204594585863362
# support: 3630
#
#
# CPU times: user 270 ms, sys: 0 ns, total: 270 ms
# Wall time: 263 ms

# %% [markdown]
# ### LogisticRegressionCV

# %%
# %%time

clf = LogisticRegressionCV(max_iter=10000)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attack
# precision: 0.8176470588235294
# recall: 0.8310911808669657
# f1-score: 0.8243143068939955
# support: 669
#
#
# defense
# precision: 0.9334485738980121
# recall: 0.941586748038361
# f1-score: 0.9374999999999999
# support: 1147
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# middle
# precision: 0.873015873015873
# recall: 0.8599857853589197
# f1-score: 0.8664518438954529
# support: 1407
#
#
# accuracy: 0.8961432506887053
#
#
# macro avg
# precision: 0.9060278764343536
# recall: 0.9081659285660616
# f1-score: 0.9070665376973621
# support: 3630
#
#
# weighted avg
# precision: 0.8961445537044889
# recall: 0.8961432506887053
# f1-score: 0.8961092329677645
# support: 3630
#
#
# CPU times: user 9min 6s, sys: 12min 33s, total: 21min 40s
# Wall time: 1min 21s

# %% [markdown]
# ### LinearSVC

# %%
# %%time

clf = LinearSVC(max_iter=10000)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attack
# precision: 0.7794117647058824
# recall: 0.8320251177394035
# f1-score: 0.8048595292331056
# support: 637
#
#
# defense
# precision: 0.9248055315471045
# recall: 0.9361329833770778
# f1-score: 0.9304347826086956
# support: 1143
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# middle
# precision: 0.8737373737373737
# recall: 0.8392238392238393
# f1-score: 0.8561329091551785
# support: 1443
#
#
# accuracy: 0.8865013774104683
#
#
# macro avg
# precision: 0.8944886674975902
# recall: 0.9018454850850801
# f1-score: 0.8978568052492448
# support: 3630
#
#
# weighted avg
# precision: 0.8874217760272777
# recall: 0.8865013774104683
# f1-score: 0.8866617808689118
# support: 3630
#
#
# CPU times: user 2.6 s, sys: 780 ms, total: 3.38 s
# Wall time: 2.2 s

# %% [markdown]
# ## Classification of "Position (13)"

# %%
X_train, X_test, y_train, y_test = dataset.get_data('Position (13)')

labels = dataset.get_labels('Position (13)')

# %% [markdown]
# ### DecisionTreeClassifier

# %%
# %%time

clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# attacking midfielder
# precision: 0.3
# recall: 0.2755102040816326
# f1-score: 0.28723404255319146
# support: 196
#
#
# central attack
# precision: 0.6870748299319728
# recall: 0.6839729119638827
# f1-score: 0.6855203619909503
# support: 443
#
#
# central defense
# precision: 0.5687022900763359
# recall: 0.5559701492537313
# f1-score: 0.5622641509433962
# support: 268
#
#
# deffensive midfielder
# precision: 0.41454545454545455
# recall: 0.3737704918032787
# f1-score: 0.3931034482758621
# support: 305
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# left attack
# precision: 0.07692307692307693
# recall: 0.06766917293233082
# f1-score: 0.07200000000000001
# support: 133
#
#
# left defense
# precision: 0.6580882352941176
# recall: 0.6462093862815884
# f1-score: 0.6520947176684881
# support: 277
#
#
# left midfielder
# precision: 0.22077922077922077
# recall: 0.2217391304347826
# f1-score: 0.2212581344902386
# support: 230
#
#
# middle
# precision: 0.034482758620689655
# recall: 0.030303030303030304
# f1-score: 0.03225806451612904
# support: 33
#
#
# midfielder
# precision: 0.47288503253796094
# recall: 0.5165876777251185
# f1-score: 0.49377123442808607
# support: 422
#
#
# right attack
# precision: 0.16393442622950818
# recall: 0.16806722689075632
# f1-score: 0.16597510373443983
# support: 119
#
#
# right defense
# precision: 0.8148148148148148
# recall: 0.8120805369127517
# f1-score: 0.8134453781512606
# support: 596
#
#
# right midfielder
# precision: 0.19246861924686193
# recall: 0.22885572139303484
# f1-score: 0.2090909090909091
# support: 201
#
#
# accuracy: 0.5606060606060606
#
#
# macro avg
# precision: 0.43113067376923175
# recall: 0.4292873569212245
# f1-score: 0.42984734968022703
# support: 3630
#
#
# weighted avg
# precision: 0.561113661655154
# recall: 0.5606060606060606
# f1-score: 0.5605206824005008
# support: 3630
#
#
# CPU times: user 370 ms, sys: 20 ms, total: 390 ms
# Wall time: 384 ms

# %% [markdown]
# ### LogisticRegressionCV

# %%
# %%time

clf = LogisticRegressionCV(max_iter=100)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# attacking midfielder
# precision: 0.4888888888888889
# recall: 0.4971751412429379
# f1-score: 0.4929971988795518
# support: 177
#
#
# central attack
# precision: 0.9297052154195011
# recall: 0.7044673539518901
# f1-score: 0.8015640273704789
# support: 582
#
#
# central defense
# precision: 0.8702290076335878
# recall: 0.6930091185410334
# f1-score: 0.7715736040609137
# support: 329
#
#
# deffensive midfielder
# precision: 0.5563636363636364
# recall: 0.6270491803278688
# f1-score: 0.5895953757225434
# support: 244
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# left attack
# precision: 0.05982905982905983
# recall: 0.21212121212121213
# f1-score: 0.09333333333333334
# support: 33
#
#
# left defense
# precision: 0.8088235294117647
# recall: 0.8148148148148148
# f1-score: 0.8118081180811809
# support: 270
#
#
# left midfielder
# precision: 0.26406926406926406
# recall: 0.3465909090909091
# f1-score: 0.29975429975429974
# support: 176
#
#
# middle
# precision: 0.0
# recall: 0.0
# f1-score: 0.0
# support: 0
#
#
# midfielder
# precision: 0.7960954446854663
# recall: 0.6495575221238938
# f1-score: 0.7153996101364523
# support: 565
#
#
# right attack
# precision: 0.040983606557377046
# recall: 0.21739130434782608
# f1-score: 0.0689655172413793
# support: 23
#
#
# right defense
# precision: 0.9276094276094277
# recall: 0.9214046822742475
# f1-score: 0.924496644295302
# support: 598
#
#
# right midfielder
# precision: 0.3472803347280335
# recall: 0.3672566371681416
# f1-score: 0.35698924731182796
# support: 226
#
#
# accuracy: 0.7107438016528925
#
#
# macro avg
# precision: 0.5453751857843082
# recall: 0.5423721443080597
# f1-score: 0.5328059212451741
# support: 3630
#
#
# weighted avg
# precision: 0.7734008497081178
# recall: 0.7107438016528925
# f1-score: 0.7363141195556548
# support: 3630
#
#
# CPU times: user 10min 9s, sys: 13min 21s, total: 23min 31s
# Wall time: 1min 28s

# %% [markdown]
# ### LinearSVC

# %%
# %%time

clf = LinearSVC(max_iter=100)
clf = clf.fit(X_train, y_train)

custom_classification_report(clf, labels, X_test, y_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# attacking midfielder
# precision: 0.45
# recall: 0.42857142857142855
# f1-score: 0.4390243902439024
# support: 189
#
#
# central attack
# precision: 0.9591836734693877
# recall: 0.6497695852534562
# f1-score: 0.7747252747252747
# support: 651
#
#
# central defense
# precision: 0.851145038167939
# recall: 0.6798780487804879
# f1-score: 0.7559322033898305
# support: 328
#
#
# deffensive midfielder
# precision: 0.31272727272727274
# recall: 0.671875
# f1-score: 0.4267990074441687
# support: 128
#
#
# goalkeeper
# precision: 1.0
# recall: 1.0
# f1-score: 1.0
# support: 407
#
#
# left attack
# precision: 0.017094017094017096
# recall: 0.125
# f1-score: 0.030075187969924817
# support: 16
#
#
# left defense
# precision: 0.8308823529411765
# recall: 0.7793103448275862
# f1-score: 0.8042704626334519
# support: 290
#
#
# left midfielder
# precision: 0.21645021645021645
# recall: 0.3968253968253968
# f1-score: 0.2801120448179272
# support: 126
#
#
# middle
# precision: 0.0
# recall: 0.0
# f1-score: 0.0
# support: 0
#
#
# midfielder
# precision: 0.8720173535791758
# recall: 0.5759312320916905
# f1-score: 0.6937014667817084
# support: 698
#
#
# right attack
# precision: 0.0
# recall: 0.0
# f1-score: 0.0
# support: 2
#
#
# right defense
# precision: 0.9393939393939394
# recall: 0.8829113924050633
# f1-score: 0.9102773246329527
# support: 632
#
#
# right midfielder
# precision: 0.28451882845188287
# recall: 0.4171779141104294
# f1-score: 0.3383084577114428
# support: 163
#
#
# accuracy: 0.6958677685950413
#
#
# macro avg
# precision: 0.5179548224826929
# recall: 0.5082500263742722
# f1-score: 0.4964019861808142
# support: 3630
#
#
# weighted avg
# precision: 0.8134785124762564
# recall: 0.6958677685950413
# f1-score: 0.7384448280093311
# support: 3630
#
#
# CPU times: user 3.02 s, sys: 1.79 s, total: 4.81 s
# Wall time: 2.05 s
